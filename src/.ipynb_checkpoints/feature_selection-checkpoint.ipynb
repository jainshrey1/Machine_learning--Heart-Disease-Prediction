# %% [markdown]
# ## Missing value imputation

# %%
import pandas as pd

from sklearn.impute import KNNImputer,SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

import re
import numpy as np

# %%
df = pd.read_csv("../data/initial_data/frmgham2_project_data.csv")

# %%
# choose only period 3
# drop time columns, also, RANDID, and Death, since the target variable is CVD
df_3 = df[df['PERIOD'] == 3]
df_3 = df_3[[col for col in df_3.columns if not re.match('TIME',col) and col not in ['RANDID','DEATH']]]

# %%
features = list(df_3.columns)
features.remove("CVD")
df_3 = df_3[features + ['CVD']]

# %%
df_3
# Out:
#        SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  DIABETES  \
# 1        1    209.0   52  121.0   66.0         0      0.0    NaN         0
# 4        2    237.0   58  108.0   66.0         0      0.0  28.50         0
# 11       2      NaN   58  155.0   90.0         1     30.0  24.61         0
# 14       2    220.0   55  180.0  106.0         0      0.0  31.17         1
# 19       2    320.0   57  110.0   46.0         1     30.0  22.02         0
# ...    ...      ...  ...    ...    ...       ...      ...    ...       ...
# 11612    1      NaN   63  120.0   80.0         1     50.0  17.38         0
# 11615    2    228.0   60  205.0  100.0         1     20.0  22.37         0
# 11618    2    251.0   56  145.0   92.0         1     35.0  21.97         0
# 11623    1    153.0   52  143.0   89.0         0      0.0  25.74         0
# 11626    2      NaN   50  147.0   96.0         1     10.0  24.19         0
#
#        BPMEDS  ...  PERIOD  HDLC   LDLC  ANGINA  HOSPMI  MI_FCHD  ANYCHD  \
# 1         0.0  ...       3  31.0  178.0       0       1        1       1
# 4         0.0  ...       3  54.0  141.0       0       0        0       0
# 11        0.0  ...       3   NaN    NaN       0       0        0       0
# 14        1.0  ...       3  46.0  135.0       0       0        1       1
# 19        0.0  ...       3  34.0  286.0       0       0        0       0
# ...       ...  ...     ...   ...    ...     ...     ...      ...     ...
# 11612     0.0  ...       3   NaN    NaN       0       0        0       0
# 11615     0.0  ...       3  47.0  181.0       0       0        0       0
# 11618     1.0  ...       3  70.0  181.0       0       0        0       0
# 11623     0.0  ...       3  30.0  123.0       0       0        0       0
# 11626     0.0  ...       3   NaN    NaN       0       0        0       0
#
#        HYPERTEN  STROKE  CVD
# 1             0       0    1
# 4             0       0    0
# 11            1       0    0
# 14            1       0    1
# 19            1       0    0
# ...         ...     ...  ...
# 11612         0       0    0
# 11615         1       0    0
# 11618         1       0    0
# 11623         1       0    0
# 11626         1       0    0
#
# [3263 rows x 28 columns]

# %%
# imput missings values
missings = df_3.isna().sum().to_frame().reset_index().rename(columns={"index":"Feature",0:"Missings"}).sort_values("Missings")
missings = missings[missings['Missings'] != 0]

missing_features = missings['Feature'].values.tolist()
missings
# Out:
#      Feature  Missings
# 10  HEARTRTE         4
# 6    CIGPDAY        14
# 7        BMI        17
# 12      educ        82
# 1    TOTCHOL       214
# 19      HDLC       236
# 20      LDLC       237
# 9     BPMEDS       446
# 11   GLUCOSE       562

# %%
missing_feaure_counts = df_3[missing_features].nunique().to_frame().reset_index()\
                .rename(columns={"index":'Feature',0:"N Unique"}).sort_values("N Unique")

missing_feaure_counts
# Out:
#     Feature  N Unique
# 7    BPMEDS         2
# 3      educ         4
# 1   CIGPDAY        35
# 0  HEARTRTE        74
# 5      HDLC       105
# 8   GLUCOSE       151
# 4   TOTCHOL       243
# 6      LDLC       262
# 2       BMI      1235

# %%
cat_missings = missing_feaure_counts[missing_feaure_counts['N Unique'] < 5]['Feature'].values
num_missings = missing_feaure_counts[missing_feaure_counts['N Unique'] > 3]['Feature'].values

# %%
imputer_num = KNNImputer()
imputer_cat = SimpleImputer(strategy='most_frequent')

# %%
X_cat,X_num = df_3[cat_missings].values,df_3[num_missings].values

X_cat = imputer_cat.fit_transform(X_cat)
X_num = imputer_num.fit_transform(X_num)

# %%
df_3_filled = df_3.copy()
df_3_filled[num_missings] = X_num
df_3_filled[cat_missings] = X_cat

# %%
# df_3_filled.isna().sum().to_frame()

# %%
X,y = df_3_filled.iloc[:,:-1].values,df_3_filled.iloc[:,-1].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=123)

scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
tree = DecisionTreeClassifier()

tree = tree.fit(X_train,y_train)

# %%
tree.feature_importances_
# Out:
# array([0.00161935, 0.01134362, 0.00752337, 0.00772428, 0.00658077,
#        0.        , 0.00866561, 0.01013802, 0.        , 0.        ,
#        0.01592619, 0.01689318, 0.00465632, 0.00240272, 0.        ,
#        0.00788827, 0.        , 0.00335672, 0.        , 0.01570531,
#        0.01490364, 0.02780012, 0.        , 0.46297667, 0.05655202,
#        0.00311191, 0.31423189])

# %%
perform_df = pd.DataFrame({features[i]:[tree.feature_importances_[i]] for i in range(len(features))}).T.reset_index().\
                        rename(columns={"index":"Feature",0:"Importance"}).sort_values("Importance")

# train_score_s,test_score_s = tree.score(X_s_train,y_s_train),tree.score(X_s_test,y_s_test)
# print(f"Missinga values have been droped, Decisoin tree:\n\t{name} data: [train score: {train_score_s}, test score: {test_score_s}]\n")

# %%
plt.figure(figsize=(14,10))

plt.bar(perform_df['Feature'],perform_df['Importance'])
plt.xticks(rotation=45)
plt.show()

# %%
rel_features = perform_df[perform_df['Importance']!=0]['Feature'].values

# %%
rel_df = df_3[rel_features+['CVD']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 rel_df = df_3[rel_features+['CVD']]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:6248, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6246 if nmissing:
#    6247     if nmissing == len(indexer):
# -> 6248         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6251     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['SEXCVD', 'PREVCHDCVD', 'HYPERTENCVD', 'PREVHYPCVD', 'educCVD',\n       'DIABPCVD', 'AGECVD', 'SYSBPCVD', 'PREVMICVD', 'CIGPDAYCVD', 'BMICVD',\n       'TOTCHOLCVD', 'LDLCCVD', 'HDLCCVD', 'HEARTRTECVD', 'GLUCOSECVD',\n       'ANGINACVD', 'ANYCHDCVD', 'STROKECVD', 'MI_FCHDCVD'],\n      dtype='object')] are in the [columns]"

# %%
# pick the feautres, which importance is not zero based on decision tree

# %%
rel_df.to_csv("../data/model_data/period_3_rel_features_df_by_tree.csv",index=False)

# %%
rel_df
# Out:
#        SEX  PREVCHD  HYPERTEN  PREVHYP  educ  DIABP  AGE  SYSBP  PREVMI  \
# 1        1        0         0        0   4.0   66.0   52  121.0       0
# 4        2        0         0        0   2.0   66.0   58  108.0       0
# 11       2        0         1        1   3.0   90.0   58  155.0       0
# 14       2        0         1        1   2.0  106.0   55  180.0       0
# 19       2        0         1        0   2.0   46.0   57  110.0       0
# ...    ...      ...       ...      ...   ...    ...  ...    ...     ...
# 11612    1        0         0        0   3.0   80.0   63  120.0       0
# 11615    2        0         1        1   2.0  100.0   60  205.0       0
# 11618    2        0         1        1   1.0   92.0   56  145.0       0
# 11623    1        0         1        1   3.0   89.0   52  143.0       0
# 11626    2        0         1        1   3.0   96.0   50  147.0       0
#
#        CIGPDAY    BMI  TOTCHOL   LDLC  HDLC  HEARTRTE  GLUCOSE  ANGINA  \
# 1          0.0    NaN    209.0  178.0  31.0      69.0     92.0       0
# 4          0.0  28.50    237.0  141.0  54.0      80.0     71.0       0
# 11        30.0  24.61      NaN    NaN   NaN      74.0      NaN       0
# 14         0.0  31.17    220.0  135.0  46.0      86.0     81.0       0
# 19        30.0  22.02    320.0  286.0  34.0      75.0     87.0       0
# ...        ...    ...      ...    ...   ...       ...      ...     ...
# 11612     50.0  17.38      NaN    NaN   NaN      76.0      NaN       0
# 11615     20.0  22.37    228.0  181.0  47.0      80.0     91.0       0
# 11618     35.0  21.97    251.0  181.0  70.0      95.0     90.0       0
# 11623      0.0  25.74    153.0  123.0  30.0      65.0     72.0       0
# 11626     10.0  24.19      NaN    NaN   NaN      94.0      NaN       0
#
#        ANYCHD  STROKE  MI_FCHD
# 1           1       0        1
# 4           0       0        0
# 11          0       0        0
# 14          1       0        1
# 19          0       0        0
# ...       ...     ...      ...
# 11612       0       0        0
# 11615       0       0        0
# 11618       0       0        0
# 11623       0       0        0
# 11626       0       0        0
#
# [3263 rows x 20 columns]

# %%
tree.score(X_test,y_test)
# Out:
# 0.9418070444104135

# %% [markdown]
# ## Our logic

# %%
from sklearn.linear_model import LogisticRegression

# %%
n_features = len(features)

for i in range(n_features):

    feature = features[i]

    inner_df = df_3[[feature,'CVD']]
