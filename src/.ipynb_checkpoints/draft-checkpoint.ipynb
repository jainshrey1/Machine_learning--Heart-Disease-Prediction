# %%
from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,f1_score,precision_score,precision_recall_curve,make_scorer

import pandas as pd

from sklearn.metrics import f1_score,cohen_kappa_score,confusion_matrix,recall_score,precision_score

# %%
perf = pd.read_csv("../src/results/first_attempt_result.csv")

# %%
perf
# Out:
#        ImputerNum     ImputerCat         Imbalance           Algorithm  \
# 0   SimpleImputer  SimpleImputer             SMOTE  LogisticRegression
# 1   SimpleImputer  SimpleImputer             SMOTE        DecisionTree
# 2   SimpleImputer  SimpleImputer             SMOTE          NaiveBayes
# 3   SimpleImputer  SimpleImputer             SMOTE                 KNN
# 4   SimpleImputer  SimpleImputer             SMOTE                 SVM
# 5   SimpleImputer  SimpleImputer  ClusterCentroids  LogisticRegression
# 6   SimpleImputer  SimpleImputer  ClusterCentroids        DecisionTree
# 7   SimpleImputer  SimpleImputer  ClusterCentroids          NaiveBayes
# 8   SimpleImputer  SimpleImputer  ClusterCentroids                 KNN
# 9   SimpleImputer  SimpleImputer  ClusterCentroids                 SVM
# 10  SimpleImputer  SimpleImputer               NaN  LogisticRegression
# 11  SimpleImputer  SimpleImputer               NaN        DecisionTree
# ...

# %%
cohen_kappa_score?
# Out:
# Signature: cohen_kappa_score(y1, y2, *, labels=None, weights=None, sample_weight=None)
# Docstring:
# Compute Cohen's kappa: a statistic that measures inter-annotator agreement.
#
# This function computes Cohen's kappa [1]_, a score that expresses the level
# of agreement between two annotators on a classification problem. It is
# defined as
#
# .. math::
#     \kappa = (p_o - p_e) / (1 - p_e)
#
# where :math:`p_o` is the empirical probability of agreement on the label
# assigned to any sample (the observed agreement ratio), and :math:`p_e` is
# the expected agreement when both annotators assign labels randomly.
# :math:`p_e` is estimated using a per-annotator empirical prior over the
# class labels [2]_.
#
# Read more in the :ref:`User Guide <cohen_kappa>`.
#
# Parameters
# ----------
# y1 : array-like of shape (n_samples,)
#     Labels assigned by the first annotator.
#
# y2 : array-like of shape (n_samples,)
#     Labels assigned by the second annotator. The kappa statistic is
# ...

# %%
pip = Pipeline([
    ("imputer",KNNImputer())
])

# %%
pip.get_params()
# Out:
# {'memory': None,
#  'steps': [('imputer', KNNImputer())],
#  'verbose': False,
#  'imputer': KNNImputer(),
#  'imputer__add_indicator': False,
#  'imputer__copy': True,
#  'imputer__keep_empty_features': False,
#  'imputer__metric': 'nan_euclidean',
#  'imputer__missing_values': nan,
#  'imputer__n_neighbors': 5,
#  'imputer__weights': 'uniform'}

# %%
KNNImputer?
# Out:
# Init signature:
# KNNImputer(
#     *,
#     missing_values=nan,
#     n_neighbors=5,
#     weights='uniform',
#     metric='nan_euclidean',
#     copy=True,
#     add_indicator=False,
#     keep_empty_features=False,
# )
# Docstring:
# Imputation for completing missing values using k-Nearest Neighbors.
#
# Each sample's missing values are imputed using the mean value from
# `n_neighbors` nearest neighbors found in the training set. Two samples are
# close if the features that neither is missing are close.
#
# Read more in the :ref:`User Guide <knnimpute>`.
#
# .. versionadded:: 0.22
#
# Parameters
# ----------
# missing_values : int, float, str, np.nan or None, default=np.nan
#     The placeholder for the missing values. All occurrences of
#     `missing_values` will be imputed. For pandas' dataframes with
#     nullable integer dtypes with missing values, `missing_values`
#     should be set to np.nan, since `pd.NA` will be converted to np.nan.
#
# n_neighbors : int, default=5
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
pip_l = Pipeline([
    ("scaler",StandardScaler()),
    ("model",LogisticRegression())
])

# %%
# GridSearchCV?

# %%
# pip_l.get_params()

# %%
# LogisticRegression?

# %%
param_grid = {
    # "model__penalty":['l1','l2','elasticnet',None],
    "model__max_iter":[100,1000,10000],
    "model__C":[.2,.5,.8,1]    
}

# %%
# scoring = {

#     "accuracy":make_scorer(accuracy_score),
#     "f1score":make_scorer(f1_score),
#     "precision_recall":make_scorer(precision_recall_curve)
# }

# %%
df = pd.read_csv("../data/model_data/period_3_rel_features_df_by_tree.csv")
df_no_na = df.dropna().copy()

X,y = df_no_na.iloc[:,:-1].values,df_no_na.iloc[:,-1]

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=123,test_size=.2)

# %%
search = GridSearchCV(pip_l,param_grid,cv=5,scoring='accuracy',refit='accuracy',error_score='raise')

# %%
search = search.fit(X_train,y_train)

# %%
search.score(X_train,y_train)
# Out:
# 0.9720357941834452

# %%
search.get_params()
# Out:
# {'cv': 5,
#  'error_score': 'raise',
#  'estimator__memory': None,
#  'estimator__steps': [('scaler', StandardScaler()),
#   ('model', LogisticRegression())],
#  'estimator__verbose': False,
#  'estimator__scaler': StandardScaler(),
#  'estimator__model': LogisticRegression(),
#  'estimator__scaler__copy': True,
#  'estimator__scaler__with_mean': True,
#  'estimator__scaler__with_std': True,
#  'estimator__model__C': 1.0,
#  'estimator__model__class_weight': None,
#  'estimator__model__dual': False,
#  'estimator__model__fit_intercept': True,
#  'estimator__model__intercept_scaling': 1,
#  'estimator__model__l1_ratio': None,
#  'estimator__model__max_iter': 100,
#  'estimator__model__multi_class': 'auto',
#  'estimator__model__n_jobs': None,
#  'estimator__model__penalty': 'l2',
#  'estimator__model__random_state': None,
#  'estimator__model__solver': 'lbfgs',
#  'estimator__model__tol': 0.0001,
#  'estimator__model__verbose': 0,
#  'estimator__model__warm_start': False,
# ...
